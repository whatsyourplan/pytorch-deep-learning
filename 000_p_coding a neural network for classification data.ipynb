# %% [markdown]
# <a href="https://colab.research.google.com/github/whatsyourplan/pytorch-deep-learning/blob/main/000_p_coding%20a%20neural%20network%20for%20classification%20data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
